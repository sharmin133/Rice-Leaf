# %% [markdown]
# <a href="https://colab.research.google.com/github/sharmin133/Rice-Leaf/blob/main/Resnet101%2BGaussian%2BCanny_final_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import os
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
import keras
from keras.preprocessing import image
from keras.models import Sequential
from keras.layers import Conv2D, MaxPool2D, Flatten,Dense,Dropout,BatchNormalization
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import cv2
from tensorflow.keras import layers, models
from keras import regularizers
from tensorflow.keras.optimizers import Adam,RMSprop,SGD,Adamax
from tensorflow.keras.applications import ResNet101

# %%
BATCH_SIZE = 32
IMAGE_SIZE = 224
CHANNELS=3
EPOCHS=25

# %%
dataset= tf.keras.preprocessing.image_dataset_from_directory(
    r"/content/drive/MyDrive/Final Thesis/Feature Extraction/Canny edge detection/gaussian+canny",
    shuffle=True,
    image_size=(IMAGE_SIZE,IMAGE_SIZE),
    batch_size=BATCH_SIZE
)
# Out:
# Found 7471 files belonging to 5 classes.

# %%
class_names= dataset.class_names
print(class_names)
len(dataset)
# Out:
# ['Bacterialblight', 'Blast', 'Brownspot', 'Tungro', '_Healthy']
# 234

# %%
for image_batch, labels_batch in dataset.take(1):
    print(image_batch.shape)
    print(labels_batch.numpy())
# Out:
# (32, 224, 224, 3)
# [4 3 3 4 2 2 4 2 0 4 1 2 0 4 3 3 4 2 3 4 1 4 0 2 2 3 2 4 0 2 3 4]

# %%
for image_batch, label_batch in dataset.take(1):
    for i in range(12):
        ax=plt.subplot(3,4,i+1)
        plt.imshow(image_batch[i].numpy().astype("uint8"))
        plt.title(class_names[label_batch[i]])
        plt.axis("off")

# %%
def get_dataset_partitions_tf(ds, train_split=0.7, val_split=0.1, test_split=0.2, shuffle=True, shuffle_size=10000):
    assert (train_split +  val_split+test_split) == 1

    ds_size = len(ds)

    if shuffle:
        ds = ds.shuffle(shuffle_size, seed=12)

    train_size = int(train_split * ds_size)
    val_size = int(val_split * ds_size)

    train_ds = ds.take(train_size)
    val_ds = ds.skip(train_size).take(val_size)
    test_ds = ds.skip(train_size).skip(val_size)

    return train_ds, val_ds, test_ds
train_ds, val_ds,test_ds= get_dataset_partitions_tf(dataset)
print(len(train_ds))
print(len(val_ds))
print(len(test_ds))
# Out:
# 163
# 23
# 48

# %%
train_ds=train_ds.cache().shuffle(1000).prefetch(buffer_size=tf.data.AUTOTUNE)
val_ds=val_ds.cache().shuffle(1000).prefetch(buffer_size=tf.data.AUTOTUNE)
test_ds=test_ds.cache().shuffle(1000).prefetch(buffer_size=tf.data.AUTOTUNE)

# %%
n_classes = len(class_names)
base_model = ResNet101(weights='imagenet', include_top=False, input_shape=(IMAGE_SIZE, IMAGE_SIZE, CHANNELS))
model =Sequential()
model.add(base_model)
model.add(Flatten())
model.add(Dense(256, activation='relu'))
model.add(Dense(n_classes, activation='softmax'))
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet101_weights_tf_dim_ordering_tf_kernels_notop.h5
# 171446536/171446536 [==============================] - 7s 0us/step

# %%
base_model.trainable=False

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  resnet101 (Functional)      (None, 7, 7, 2048)        42658176
#
#  flatten (Flatten)           (None, 100352)            0
#
#  dense (Dense)               (None, 256)               25690368
#
#  dense_1 (Dense)             (None, 5)                 1285
#
# =================================================================
# Total params: 68349829 (260.73 MB)
# Trainable params: 25691653 (98.01 MB)
# Non-trainable params: 42658176 (162.73 MB)
# _________________________________________________________________

# %%
model.compile(
    optimizer = Adam(learning_rate=0.001),
    loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False),
    metrics=['accuracy']
)

# %%
history = model.fit(
    train_ds,
    batch_size=BATCH_SIZE,
    validation_data=val_ds,
    verbose=1,
    epochs=25,
)
# Out:
# Epoch 1/25
# 163/163 [==============================] - 929s 145ms/step - loss: 3.9520 - accuracy: 0.7998 - val_loss: 0.8912 - val_accuracy: 0.8414
# Epoch 2/25
# 163/163 [==============================] - 11s 65ms/step - loss: 0.2645 - accuracy: 0.9490 - val_loss: 0.2428 - val_accuracy: 0.9513
# Epoch 3/25
# 163/163 [==============================] - 11s 65ms/step - loss: 0.0957 - accuracy: 0.9777 - val_loss: 0.2514 - val_accuracy: 0.9458
# Epoch 4/25
# 163/163 [==============================] - 11s 65ms/step - loss: 0.0742 - accuracy: 0.9827 - val_loss: 0.0994 - val_accuracy: 0.9694
# Epoch 5/25
# 163/163 [==============================] - 11s 65ms/step - loss: 0.0630 - accuracy: 0.9844 - val_loss: 0.3571 - val_accuracy: 0.9708
# Epoch 6/25
# 163/163 [==============================] - 11s 65ms/step - loss: 0.0897 - accuracy: 0.9823 - val_loss: 0.2203 - val_accuracy: 0.9708
# Epoch 7/25
# 163/163 [==============================] - 11s 65ms/step - loss: 0.0400 - accuracy: 0.9875 - val_loss: 0.1852 - val_accuracy: 0.9611
# Epoch 8/25
# 163/163 [==============================] - 11s 65ms/step - loss: 0.1232 - accuracy: 0.9735 - val_loss: 0.0975 - val_accuracy: 0.9819
# Epoch 9/25
# 163/163 [==============================] - 11s 65ms/step - loss: 0.0323 - accuracy: 0.9908 - val_loss: 0.1023 - val_accuracy: 0.9764
# Epoch 10/25
# 163/163 [==============================] - 11s 65ms/step - loss: 0.0164 - accuracy: 0.9937 - val_loss: 0.0845 - val_accuracy: 0.9833
# Epoch 11/25
# 163/163 [==============================] - 11s 65ms/step - loss: 0.0583 - accuracy: 0.9881 - val_loss: 0.1005 - val_accuracy: 0.9847
# Epoch 12/25
# 163/163 [==============================] - 11s 65ms/step - loss: 0.0600 - accuracy: 0.9846 - val_loss: 0.1745 - val_accuracy: 0.9680
# Epoch 13/25
# 163/163 [==============================] - 11s 65ms/step - loss: 0.0707 - accuracy: 0.9838 - val_loss: 0.1952 - val_accuracy: 0.9750
# Epoch 14/25
# 163/163 [==============================] - 11s 65ms/step - loss: 0.1429 - accuracy: 0.9736 - val_loss: 0.3121 - val_accuracy: 0.9569
# Epoch 15/25
# 163/163 [==============================] - 11s 65ms/step - loss: 0.1299 - accuracy: 0.9802 - val_loss: 0.1837 - val_accuracy: 0.9666
# Epoch 16/25
# 163/163 [==============================] - 11s 65ms/step - loss: 0.2180 - accuracy: 0.9765 - val_loss: 0.4348 - val_accuracy: 0.9611
# Epoch 17/25
# 163/163 [==============================] - 11s 65ms/step - loss: 0.1051 - accuracy: 0.9856 - val_loss: 0.1621 - val_accuracy: 0.9777
# Epoch 18/25
# 163/163 [==============================] - 11s 65ms/step - loss: 0.0199 - accuracy: 0.9938 - val_loss: 0.1310 - val_accuracy: 0.9819
# Epoch 19/25
# 163/163 [==============================] - 11s 65ms/step - loss: 0.0157 - accuracy: 0.9940 - val_loss: 0.1201 - val_accuracy: 0.9833
# Epoch 20/25
# 163/163 [==============================] - 11s 65ms/step - loss: 0.0132 - accuracy: 0.9948 - val_loss: 0.1171 - val_accuracy: 0.9847
# Epoch 21/25
# 163/163 [==============================] - 11s 65ms/step - loss: 0.0129 - accuracy: 0.9948 - val_loss: 0.1199 - val_accuracy: 0.9833
# Epoch 22/25
# 163/163 [==============================] - 11s 65ms/step - loss: 0.0133 - accuracy: 0.9948 - val_loss: 0.1193 - val_accuracy: 0.9833
# Epoch 23/25
# 163/163 [==============================] - 11s 65ms/step - loss: 0.0134 - accuracy: 0.9948 - val_loss: 0.1183 - val_accuracy: 0.9833
# Epoch 24/25
# 163/163 [==============================] - 11s 65ms/step - loss: 0.0131 - accuracy: 0.9948 - val_loss: 0.1233 - val_accuracy: 0.9833
# Epoch 25/25
# 163/163 [==============================] - 11s 65ms/step - loss: 0.0130 - accuracy: 0.9948 - val_loss: 0.1228 - val_accuracy: 0.9833

# %%
scores = model.evaluate(test_ds)
# Out:
# 48/48 [==============================] - 14s 59ms/step - loss: 0.0857 - accuracy: 0.9850

# %%
scores
# Out:
# [0.08571004867553711, 0.9850260615348816]

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

# %%
plt.figure(figsize=(14, 6))
plt.subplot(1, 2, 1)
plt.plot(range(EPOCHS), acc, label='Training Accuracy')
plt.plot(range(EPOCHS), val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(range(EPOCHS), loss, label='Training Loss')
plt.plot(range(EPOCHS), val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
import numpy as np
for images_batch, labels_batch in test_ds.take(1):

    first_image = images_batch[0].numpy().astype('uint8')
    first_label = labels_batch[0].numpy()

    print("first image to predict")
    plt.imshow(first_image)
    print("actual label:",class_names[first_label])

    batch_prediction = model.predict(images_batch)
    print("predicted label:",class_names[np.argmax(batch_prediction[0])])
# Out:
# first image to predict
# actual label: _Healthy
# 1/1 [==============================] - 2s 2s/step
# predicted label: _Healthy

# %%
import numpy as np
from sklearn.metrics import confusion_matrix
import seaborn as sns
test_images = []
test_labels = []

for images, labels in test_ds:
    test_images.append(images.numpy())
    test_labels.append(labels.numpy())

test_images = np.concatenate(test_images)
test_labels = np.concatenate(test_labels)
predicted_labels = np.argmax(model.predict(test_images), axis=-1)
cm = confusion_matrix(test_labels, predicted_labels)
cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='.2f', cmap='Blues', xticklabels=class_names, yticklabels=class_names)
plt.xlabel('Predicted labels')
plt.ylabel('True labels')
plt.title('Normalized Confusion Matrix')
plt.show()
# Out:
# 48/48 [==============================] - 3s 54ms/step

# %%
from sklearn.metrics import classification_report
target_names = class_names
report = classification_report(test_labels, predicted_labels, target_names=target_names)
print("Classification Report:\n", report)
# Out:
# Classification Report:
#                   precision    recall  f1-score   support
#
# Bacterialblight       0.99      1.00      0.99       323
#           Blast       0.99      0.92      0.96       258
#       Brownspot       0.96      0.99      0.98       366
#          Tungro       0.99      1.00      0.99       283
#        _Healthy       1.00      1.00      1.00       306
#
#        accuracy                           0.99      1536
#       macro avg       0.99      0.98      0.98      1536
#    weighted avg       0.99      0.99      0.98      1536
